# %% [markdown]
# # Problem 1
# Sözlükleri kullanarak bir telefon rehberi yazın. Bu rehberde kullanıcıya kimin telefonunu görüntülemek istediğini sorun ve kullanıcının girdiği isme göre o kişinin telefon numarasını yazdırın. Proje sonunda elde edeceğiniz çıktı  şuna benzer olmalı:
#
#
# Lütfen numarasını öğrenmek istediğiniz kişinin adını girin: Ahmet
#
# Ahmet isimli kişinin numarası şu şekildedir: 0532 678 13 19

# %%
rehber = {"Ahmet" : "0532 678 13 19", "Serra" : "0534 284 55 60", "Ali" : "0237 983 24 24"}
numara = input("Numarasini ogrenmek istediginiz kisinin adini girin: ")

if numara in rehber:
    print(f"{numara} isimli kisinin numarasi :", rehber[numara])
else:
    print("Bu kisi rehberinizde kayitli degildir")
# Out:
# Ahmet isimli kisinin numarasi : 0532 678 13 19

# %% [markdown]
# # Problem 2
# Sözlükleri kullanarak bir şirket çalışanları indeksi oluşturun. Bu isim indeksinde kişilerin isimleri key, kişilerin  memleket, yaş ve görev bilgileri value olmalıdır. Burada kullanacağımız value değerleri liste olmalıdır.
#
#
# Daha sonra bir isim sorgulama ekranı gibi kullanıcıya kimin bilgilerini görüntülemek istediğini
# sorun ve sorgulanan kişinin ekranda gösterilmesini sağlayın. Proje sonunda elde edeceğiniz çıktı şu şekilde olmalı:
#
#
# Lütfen bilgilerini görüntülemek istediğiniz çalışanın ismini girin: Mehmet Yağız
#
# Mehmet Yağız= Memleket: Adana Yaş: 40 Görev: Direktör

# %%
sirketCalisanlari = {"Mehmet Yagiz": "Memleket: Adana Yas: 40 Gorev: Direktor", "Serra Us": "Memleket: Istanbul Yas: 18 Gorev: Stajyer", "Sevgi Kara": "Memleket: Kayseri Yas: 34 Gorev: Yonetici Asistani"}
isim = input("Lütfen bilgilerini görüntülemek istediğiniz çalışanın ismini girin: ")
if isim in sirketCalisanlari:
    print(f"{isim} = ", sirketCalisanlari[isim])
else: 
    print("Sirketimizde oyle bir calisan bulunmamaktadir")
# Out:
# Mehmet Yagiz =  Memleket: Adana Yas: 40 Gorev: Direktor

# %% [markdown]
# # Problem 3
#
# 3 öğrenciden oluşan bir öğrenci not sözlüğü oluşturun. Bu sözlükte öğrencilerin notları value olarak bir listede toplansın.
#
# Kullanıcıya hangi öğrencinin notlarını görmek istediğini sorun. Öğrencinin notu görüntülendiğinde program sonunda şöyle bir çıktı elde etmelisiniz:
#
# ```
# Lütfen notlarını görmek istediğiniz öğrencinin adını girin: Mehmet
#
# Mehmet isimli öğrencinin      1.Sınav Notu:72
#                               2.Sınav Notu:66
#                               3.Sınav Notu:48
# Not Ortalaması: 62.0

# %%
notlar = {"Mehmet" : [72, 66, 48], "Serra" : [95, 83, 90]}
isim = input("Lutfen notlarini gormek istediginiz ogrencinin adini girin: ")
print(f"{isim} isimli ogrencinin: ")
print("1. Sinav notu:", notlar[isim][0])
print("2. Sinav notu:", notlar[isim][1])
print("3. Sinav notu:", notlar[isim][2])
notOrtalamasi = (notlar[isim][0] + notlar[isim][1] + notlar[isim][2]) / len(notlar[isim])
print("Not Ortalamasi: ", notOrtalamasi)
# Out:
# Mehmet isimli ogrencinin:
# 1. Sinav notu: 72
# 2. Sinav notu: 66
# 3. Sinav notu: 48
# Not Ortalamasi:  62.0

# %% [markdown]
# # Problem 4

# %%
arabalar = ["Bmw", "Mercedes", "Opel", "Mazda"]    # 1-  "Bmw, Mercedes, Opel, Mazda" elemanlarına sahip bir liste oluşturunuz.

print(len(arabalar))                               # 2-  Liste Kaç elemanlıdır ?

print(arabalar[0])
print(arabalar[-1])                                # 3-  Listenin ilk ve son elemanı nedir ?

arabalar.insert(-1,"Toyota")
arabalar.remove("Mazda")
print(arabalar)                        # 4-  Mazda değerini Toyota ile değiştirin.

print(arabalar[-2])                                                 # 5-  Listenin -2 indeksindeki değer nedir ?

print(arabalar[0:4])                                                # 6-  Listenin ilk 3 elemanını alın.

arabalar.pop()
arabalar.pop()
arabalar.append("Toyota")
arabalar.append("Renault")
print(arabalar) # 7-  Listenin son 2 elemanı yerine "Toyota" ve "Renault" değerlerini ekleyin.

arabalar.append("Audi")
arabalar.append("Nissan")
print(arabalar) # 8-  Listenin üzerine "Audi" ve "Nissan" değerlerini ekleyin.

arabalar.pop()
print(arabalar)                                       # 9- Listenin son elemanını silin.

arabalar.reverse()
print(arabalar) # 10- Liste elemanlarını tersten yazdırınız.

 

students = ["studentA:", "Yigit Bilgi", 2010, (70,60,70), "studentB:", "Sena Turan", 1999, (80,80,70), "studentC:", "Ahmet Turan", 1998, (80,70,90)]                           # 11- Aşağıdaki verileri bir liste içinde saklayınız. 
print(students)
                                # studentA: Yiğit Bilgi 2010, (70,60,70)
                                # studentB: Sena Turan  1999, (80,80,70)
                                # studentC: Ahmet Turan 1998, (80,70,90) 

# 12- Liste elemanlarını ekrana yazdırınız.



  
names = ['Ali','Yağmur','Hakan','Deniz']
years = [1998, 2000, 1998, 1987]

names.append("Cenk")
print(names)             # 13-  "Cenk" ismini listenin sonuna ekleyiniz.


names.insert(0,"Sena")
print(names)                               # 14-  "Sena" değerini listenin başına ekleyiniz.


names.remove("Deniz")
print(names)                            # 15-  "Deniz" ismini listeden siliniz.


print(names.index("Ali"))                               # 16-  "Ali" listenin bir elemanı mıdır ?

names.reverse()
print(names)           # 17-  Liste elemanlarını ters çevirin.

names.sort()
print(names)           # 18-  Liste elemanlarını alfabetik olarak sıralayınız.


years.sort()
print(years)             # 19-  years listesini rakamsal büyüklüğe göre sıralayınız.

str = "Chevrolet, Dacia"   
print([str])                   # 20-  str = "Chevrolet,Dacia" karakter dizisini listeye çeviriniz.


print(years.count(1998))                      # 21- years dizisinde kaç tane 1998 değeri vardır ?


years.clear()
print(years)            # 22- years dizisinin tüm elemanlarını siliniz.


marka1 = input("Bir marka giriniz: ") 
marka2 = input("Bir marka giriniz: ")  
marka3 = input("Bir marka giriniz: ")                                  # 23- Kullanıcıdan alacağınız 3 tane marka bilgisini bir listede saklayınız.
print([marka1, marka2, marka3])
# Out:
# 4
# Bmw
# Mazda
# ['Bmw', 'Mercedes', 'Opel', 'Toyota']
# Opel
# ['Bmw', 'Mercedes', 'Opel', 'Toyota']
# ['Bmw', 'Mercedes', 'Toyota', 'Renault']
# ['Bmw', 'Mercedes', 'Toyota', 'Renault', 'Audi', 'Nissan']
# ['Bmw', 'Mercedes', 'Toyota', 'Renault', 'Audi']
# ['Audi', 'Renault', 'Toyota', 'Mercedes', 'Bmw']
# ['studentA:', 'Yigit Bilgi', 2010, (70, 60, 70), 'studentB:', 'Sena Turan', 1999, (80, 80, 70), 'studentC:', 'Ahmet Turan', 1998, (80, 70, 90)]
# ['Ali', 'Yağmur', 'Hakan', 'Deniz', 'Cenk']
# ['Sena', 'Ali', 'Yağmur', 'Hakan', 'Deniz', 'Cenk']
# ['Sena', 'Ali', 'Yağmur', 'Hakan', 'Cenk']
# 1
# ['Cenk', 'Hakan', 'Yağmur', 'Ali', 'Sena']
# ['Ali', 'Cenk', 'Hakan', 'Sena', 'Yağmur']
# [1987, 1998, 1998, 2000]
# ['Chevrolet, Dacia']
# 2
# []
# ['Tesla', 'Toyota', 'Audi']
