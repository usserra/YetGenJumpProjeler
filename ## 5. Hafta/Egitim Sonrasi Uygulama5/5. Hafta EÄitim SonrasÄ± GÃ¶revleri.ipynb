# %% [markdown]
# # Problem 1
#
# Fizikte, bir nesnenin sabit ivmeyle hareket ederken son hızını
# (veya hızını) bulmak için aşağıdaki denklem kullanılabilir:
# ```
# vf = vi + at
# burada:
# vf= son hız
# vi= ilk hız
# a= hızlanma
# t= zaman
# ```
# İlk hız, ivme ve zaman verildiğinde, son hızı döndürecek bir fonksiyon yazın.

# %%
vi = float(input("Ilk Hiz: "))
a = float(input("Hizlanma: "))
t = float(input("Zaman: "))
def finalSpeed(vi,a,t):
    sonHiz = vi +  a * t
    print("Son hiz: ", sonHiz)
finalSpeed(vi,a,t)
# Out:
# Son hiz:  17.0

# %%
def finalSpeed(vi,a,t):
    sonHiz = vi +  a * t
    print(sonHiz)
finalSpeed(9,3,10)
# Out:
# 39

# %% [markdown]
# # Problem 2
#
# 1'den 1000'e kadar olan sayılardan mükemmel sayı olanları ekrana yazdırın. Bunun için bir sayının mükemmel olup olmadığını dönen bir tane fonksiyon yazın.
#
# Bir sayının bölenlerinin toplamı kendine eşitse bu sayı mükemmel bir sayıdır. Örnek olarak 6 mükemmel bir sayıdır (1 + 2 + 3 = 6).

# %%
def mukemmel_mi(sayi):
    toplam = 0
    for i in range (1,sayi):
        if sayi % i == 0:
            toplam +=i
    return toplam == sayi
for i in range (1,1001):
    if mukemmel_mi(i):
        print("Mukemmel Sayi: ", i)
# Out:
# Mukemmel Sayi:  6
# Mukemmel Sayi:  28
# Mukemmel Sayi:  496

# %%
def mukemmelSayi(x: int):
    toplam = 0
    for num in range (1,1001):
        if x % num == 0 and num != x:
            toplam += num 
    if toplam == x:
        return toplam

    
    
for x in mukemmelSayi(x):
    print(toplam)

# %%
def mukemmel_sayi_kontrol(x: str):
    sum_variable = 0
    for x in range (1,1001):
        for i in range(1,x):
            if x % i == 0:
                sum_variable = sum_variable + i
            return x
        if sum_variable == x:
            print(x)
    return sum_variable

        

mukemmel_sayi_kontrol(x)
# Out:
# 2

# %%
def mukemmelSayi(x):
    
    toplam = 0
    
    for x in range (1,1001):
        for num in range (1,x):
            if x % num == 0 and num != x:
                toplam += num 
        if toplam == x:
            print(toplam)
    return toplam
    
for x in range(1,1001):
    if mukemmelSayi(x):
        print("Mukemmel Sayi:" , x)
# Out:
# Mukemmel Sayi: 1
# Mukemmel Sayi: 2
# Mukemmel Sayi: 3
# Mukemmel Sayi: 4
# Mukemmel Sayi: 5
# Mukemmel Sayi: 6
# Mukemmel Sayi: 7
# Mukemmel Sayi: 8
# Mukemmel Sayi: 9
# Mukemmel Sayi: 10
# Mukemmel Sayi: 11
# Mukemmel Sayi: 12
# Mukemmel Sayi: 13
# Mukemmel Sayi: 14
# Mukemmel Sayi: 15
# Mukemmel Sayi: 16
# Mukemmel Sayi: 17
# Mukemmel Sayi: 18
# Mukemmel Sayi: 19
# Mukemmel Sayi: 20
# Mukemmel Sayi: 21
# Mukemmel Sayi: 22
# Mukemmel Sayi: 23
# Mukemmel Sayi: 24
# Mukemmel Sayi: 25
# Mukemmel Sayi: 26
# Mukemmel Sayi: 27
# Mukemmel Sayi: 28
# Mukemmel Sayi: 29
# Mukemmel Sayi: 30
# Mukemmel Sayi: 31
# Mukemmel Sayi: 32
# Mukemmel Sayi: 33
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 3433, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/var/folders/z5/pt2g83752rqbf35mxd4x57_40000gn/T/ipykernel_82376/136595820.py", line 14, in <module>
#     if mukemmelSayi(x):
#        ^^^^^^^^^^^^^^^
#   File "/var/folders/z5/pt2g83752rqbf35mxd4x57_40000gn/T/ipykernel_82376/136595820.py", line -1, in mukemmelSayi
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/IPython/core/interactiveshell.py", line 2052, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/IPython/core/ultratb.py", line 1112, in structured_traceback
#     return FormattedTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/IPython/core/ultratb.py", line 1006, in structured_traceback
#     return VerboseTB.structured_traceback(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/IPython/core/ultratb.py", line 859, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#                           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/IPython/core/ultratb.py", line 812, in format_exception_as_a_whole
#     frames.append(self.format_record(r))
#                   ^^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/IPython/core/ultratb.py", line 730, in format_record
#     result += ''.join(_format_traceback_lines(frame_info.lines, Colors, self.has_colors, lvals))
#                                               ^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/stack_data/utils.py", line 144, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#                                                ^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/stack_data/core.py", line 720, in lines
#     pieces = self.included_pieces
#              ^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/stack_data/utils.py", line 144, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#                                                ^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/stack_data/core.py", line 667, in included_pieces
#     pos = scope_pieces.index(self.executing_piece)
#                              ^^^^^^^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/stack_data/utils.py", line 144, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#                                                ^^^^^^^^^^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/stack_data/core.py", line 646, in executing_piece
#     return only(
#            ^^^^^
#   File "/Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/executing/executing.py", line 190, in only
#     raise NotOneValueFound('Expected one value, found 0')
# executing.executing.NotOneValueFound: Expected one value, found 0

# %%
def mukemmelSayi():
    toplam = 0
    for num in range (1,1001):
        if x % num == 0 and num != x:
            toplam += num 
    if toplam == x:
        print(toplam)
    return toplam

    
     
for x in mukemmelSayi():
    print(x)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/serraus/Documents/GitHub/YetGenJumpProjeler/## 5. Hafta/Egitim Sonrasi Uygulama5/5. Hafta EÄitim SonrasÄ± GÃ¶revleri.ipynb Cell 7 in 1
#       <a href='vscode-notebook-cell:/Users/serraus/Documents/GitHub/YetGenJumpProjeler/%23%23%205.%20Hafta/Egitim%20Sonrasi%20Uygulama5/5.%20Hafta%20E%C3%84%C2%9Fitim%20Sonras%C3%84%C2%B1%20G%C3%83%C2%B6revleri.ipynb#W3sZmlsZQ%3D%3D?line=6'>7</a>         print(toplam)
#       <a href='vscode-notebook-cell:/Users/serraus/Documents/GitHub/YetGenJumpProjeler/%23%23%205.%20Hafta/Egitim%20Sonrasi%20Uygulama5/5.%20Hafta%20E%C3%84%C2%9Fitim%20Sonras%C3%84%C2%B1%20G%C3%83%C2%B6revleri.ipynb#W3sZmlsZQ%3D%3D?line=7'>8</a>     return toplam
# ---> <a href='vscode-notebook-cell:/Users/serraus/Documents/GitHub/YetGenJumpProjeler/%23%23%205.%20Hafta/Egitim%20Sonrasi%20Uygulama5/5.%20Hafta%20E%C3%84%C2%9Fitim%20Sonras%C3%84%C2%B1%20G%C3%83%C2%B6revleri.ipynb#W3sZmlsZQ%3D%3D?line=11'>12</a> for x in mukemmelSayi():
#      <a href='vscode-notebook-cell:/Users/serraus/Documents/GitHub/YetGenJumpProjeler/%23%23%205.%20Hafta/Egitim%20Sonrasi%20Uygulama5/5.%20Hafta%20E%C3%84%C2%9Fitim%20Sonras%C3%84%C2%B1%20G%C3%83%C2%B6revleri.ipynb#W3sZmlsZQ%3D%3D?line=12'>13</a>     print(x)
#
# TypeError: 'int' object is not iterable

# %% [markdown]
# # Problem 3
#
# 1'den 100'e kadar olan sayılardan pisagor üçgeni oluşturanları ekrana yazdıran bir fonksiyon yazın.(a <= 100,b <= 100)

# %%
def pisagor_bulma():
    pisagor_listesi = list()
    for i in range(1, 101):
        for j in range(1, 101):

            c = (i ** 2 + j ** 2) ** 0.5

            if (c == int(c)): #c tam sayi ise
                pisagor_listesi.append((i, j, int(c)))

    return pisagor_listesi


for i in pisagor_bulma():
    print(i)
# Out:
# (3, 4, 5)
# (4, 3, 5)
# (5, 12, 13)
# (6, 8, 10)
# (7, 24, 25)
# (8, 6, 10)
# (8, 15, 17)
# (9, 12, 15)
# (9, 40, 41)
# (10, 24, 26)
# (11, 60, 61)
# (12, 5, 13)
# (12, 9, 15)
# (12, 16, 20)
# (12, 35, 37)
# (13, 84, 85)
# (14, 48, 50)
# (15, 8, 17)
# (15, 20, 25)
# (15, 36, 39)
# (16, 12, 20)
# (16, 30, 34)
# (16, 63, 65)
# (18, 24, 30)
# (18, 80, 82)
# (20, 15, 25)
# (20, 21, 29)
# (20, 48, 52)
# (20, 99, 101)
# (21, 20, 29)
# (21, 28, 35)
# (21, 72, 75)
# (24, 7, 25)
# (24, 10, 26)
# (24, 18, 30)
# (24, 32, 40)
# (24, 45, 51)
# (24, 70, 74)
# (25, 60, 65)
# (27, 36, 45)
# (28, 21, 35)
# (28, 45, 53)
# (28, 96, 100)
# (30, 16, 34)
# (30, 40, 50)
# (30, 72, 78)
# (32, 24, 40)
# (32, 60, 68)
# (33, 44, 55)
# (33, 56, 65)
# (35, 12, 37)
# (35, 84, 91)
# (36, 15, 39)
# (36, 27, 45)
# (36, 48, 60)
# (36, 77, 85)
# (39, 52, 65)
# (39, 80, 89)
# (40, 9, 41)
# (40, 30, 50)
# (40, 42, 58)
# (40, 75, 85)
# (40, 96, 104)
# (42, 40, 58)
# (42, 56, 70)
# (44, 33, 55)
# (45, 24, 51)
# (45, 28, 53)
# (45, 60, 75)
# (48, 14, 50)
# (48, 20, 52)
# (48, 36, 60)
# (48, 55, 73)
# (48, 64, 80)
# (48, 90, 102)
# (51, 68, 85)
# (52, 39, 65)
# (54, 72, 90)
# (55, 48, 73)
# (56, 33, 65)
# (56, 42, 70)
# (56, 90, 106)
# (57, 76, 95)
# (60, 11, 61)
# (60, 25, 65)
# (60, 32, 68)
# (60, 45, 75)
# (60, 63, 87)
# (60, 80, 100)
# (60, 91, 109)
# (63, 16, 65)
# (63, 60, 87)
# (63, 84, 105)
# (64, 48, 80)
# (65, 72, 97)
# (66, 88, 110)
# (68, 51, 85)
# (69, 92, 115)
# (70, 24, 74)
# (72, 21, 75)
# (72, 30, 78)
# (72, 54, 90)
# (72, 65, 97)
# (72, 96, 120)
# (75, 40, 85)
# (75, 100, 125)
# (76, 57, 95)
# (77, 36, 85)
# (80, 18, 82)
# (80, 39, 89)
# (80, 60, 100)
# (80, 84, 116)
# (84, 13, 85)
# (84, 35, 91)
# (84, 63, 105)
# (84, 80, 116)
# (88, 66, 110)
# (90, 48, 102)
# (90, 56, 106)
# (91, 60, 109)
# (92, 69, 115)
# (96, 28, 100)
# (96, 40, 104)
# (96, 72, 120)
# (99, 20, 101)
# (100, 75, 125)

# %% [markdown]
# # Problem 4
#
# Bir duvar boyamaya karar verdiniz. Boya kutusunun üzerindeki talimatta, 1 kutu boyanın 5 metrekarelik bir duvarı boyayabileceği yazıyor. Rastgele bir duvar yüksekliği ve genişliği verildiğinde, kaç kutu boya satın almanız gerektiğini hesaplayın.
#
# kutu sayısı = (duvar yüksekliği * duvar genişliği) ÷ kutu başına kaplama.
#
# örneğin Yükseklik = 2, Genişlik = 4, Kaplama = 5
#
# kutu sayısı = (2 * 4) ÷ 5 = 1.6
#
# Ancak bir kutu boyanın 0,6'sını satın alamayacağınız için, sonuç 2 kutuya yuvarlanmalıdır .

# %%
import math
def boyama(y,g,k):
    alan = y * g
    kutuSayisi = math.ceil(alan/k) #math.ceil yukari yuvarlar
    print(f"{kutuSayisi} kutu boyaya ihtiyaciniz var")
y = int(input("Yukseklik: "))
g = int(input("Genislik: "))
k = 5 #soruya gore degismiyor hep 5
boyama(y,g,k)
# Out:
# 2 kutu boyaya ihtiyaciniz var

# %%
def kutuSayisi(x,y,z):
    kutu = (x*y)/z
    print(round((kutu)))
kutuSayisi(2,4,5) #bu yontemle 2.4 2 ye yuvarlaniyor ama biz hep bi uste yuvarlanmasini istiyoruz
# Out:
# 2

# %% [markdown]
# # Problem 5
#
# Bir kelimedeki ünlü ve ünsüz harfleri sayan bir fonksiyon yazınız.

# %%
def count(val):
    vov = 0
    con = 0
    for i in range(len(val)): #kelimenin eleman sayisi kadar gezicez
        if val[i] in ['a','e','i','o','u']: #kelimenin icindeki harflerde bu harflere esit bi harf var mi, eger varsa sesli harfleri bir arttir
            vov = vov+1
        else:
            con = con+1
    print("Unlu harf sayisi: ", vov)
    print("Unsuz harf sayisi: ", con)
x = input("Kelime giriniz").lower()
count(x)

# %%
def kelimeHarf(x):
    kelime = x
    yenikelime = kelime.lower()
    unluHarf = []
    unsuzHarf = []
    print(yenikelime)
    for harf in yenikelime:
        if harf in "aeiou":
            
            unluHarf.append(harf)
            
        else:
            
            unsuzHarf.append(harf)
        
    print("Kelimedeki unlu harf sayisi: ", len(unluHarf))
    print("Kelimedeki unsuz harf sayisi: ", len(unsuzHarf))
kelimeHarf("Hello")
# Out:
# hello
# Kelimedeki unlu harf sayisi:  2
# Kelimedeki unsuz harf sayisi:  3

# %% [markdown]
# # Problem 6
#
# Verilen bir listeden çift sayıları yazdıran bir fonksiyon yazınız.

# %%
def ciftSayi(*x): #* a gerek yok eger yesilleri takip edeceksek
    liste = []
    for num in x:
        if num%2 ==0:
            liste.append(num)
    print(liste) #return liste de olur
ciftSayi(1,2,3,4,5,6) #tepede return liste yaparsan burda da parantez icine sayilari liste olarak gir
# Out:
# [2, 4, 6]

# %% [markdown]
# # Problem 7
#
# 0'dan 10'a kadar olan sayıların toplamını hesaplayan özyinelemeli (Recursive Function) bir fonksiyon oluşturan bir fonksiyon yazınız.
#
# Özyinelemeli (Recursive Function) bir işlev, kendini tekrar tekrar çağıran bir işlevdir.

# %%
def addition(num):
    if num: #num true ise demek
        return num + addition(num-1) #num a 10 diyo, 10 + 9, sonra num a 9 diyo 9+8...
    else:
        return 0

res = addition(10)
print(res)
# Out:
# 55

# %%
def toplam(x):
   
   if x <= 0:
      return x
   return x + toplam(x-1)
x = 10

toplam(10)
# Out:
# 55
