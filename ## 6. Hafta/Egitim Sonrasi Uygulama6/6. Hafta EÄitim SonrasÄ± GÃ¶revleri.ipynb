# %% [markdown]
# # Problem 1
# Bir sayının çift olup olmadığını sorgulayan bir fonksiyon yazın. Bu fonksiyon, eğer sayı çift ise bu değeri dönsün. Ancak sayı tek sayı ise fonksiyon raise ile ValueError hatası oluştursun. Daha sonra, içinde çift ve tek sayılar bulunduran bir liste tanımlayın ve liste üzerinde gezinerek ekrana sadece çift sayıları bastırın.

# %%
def cift_mi(sayi):
    
    for num in sayi:
        if num % 2 == 0:
            print(num)
        else:
            raise ValueError ("Listede tek sayi var")
    


cift_mi([2,3,4,5,6,7,8,9,10])
# Out:
# 2
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/serraus/Documents/GitHub/YetGenJumpProjeler/## 6. Hafta/Egitim Sonrasi Uygulama6/6. Hafta EÄitim SonrasÄ± GÃ¶revleri.ipynb Cell 2 in 1
#       <a href='vscode-notebook-cell:/Users/serraus/Documents/GitHub/YetGenJumpProjeler/%23%23%206.%20Hafta/Egitim%20Sonrasi%20Uygulama6/6.%20Hafta%20E%C3%84%C2%9Fitim%20Sonras%C3%84%C2%B1%20G%C3%83%C2%B6revleri.ipynb#W1sZmlsZQ%3D%3D?line=5'>6</a>         else:
#       <a href='vscode-notebook-cell:/Users/serraus/Documents/GitHub/YetGenJumpProjeler/%23%23%206.%20Hafta/Egitim%20Sonrasi%20Uygulama6/6.%20Hafta%20E%C3%84%C2%9Fitim%20Sonras%C3%84%C2%B1%20G%C3%83%C2%B6revleri.ipynb#W1sZmlsZQ%3D%3D?line=6'>7</a>             raise ValueError ("Listede tek sayi var")
# ---> <a href='vscode-notebook-cell:/Users/serraus/Documents/GitHub/YetGenJumpProjeler/%23%23%206.%20Hafta/Egitim%20Sonrasi%20Uygulama6/6.%20Hafta%20E%C3%84%C2%9Fitim%20Sonras%C3%84%C2%B1%20G%C3%83%C2%B6revleri.ipynb#W1sZmlsZQ%3D%3D?line=10'>11</a> cift_mi([2,3,4,5,6,7,8,9,10])
#
# /Users/serraus/Documents/GitHub/YetGenJumpProjeler/## 6. Hafta/Egitim Sonrasi Uygulama6/6. Hafta EÄitim SonrasÄ± GÃ¶revleri.ipynb Cell 2 in 7
#       <a href='vscode-notebook-cell:/Users/serraus/Documents/GitHub/YetGenJumpProjeler/%23%23%206.%20Hafta/Egitim%20Sonrasi%20Uygulama6/6.%20Hafta%20E%C3%84%C2%9Fitim%20Sonras%C3%84%C2%B1%20G%C3%83%C2%B6revleri.ipynb#W1sZmlsZQ%3D%3D?line=4'>5</a>     print(num)
#       <a href='vscode-notebook-cell:/Users/serraus/Documents/GitHub/YetGenJumpProjeler/%23%23%206.%20Hafta/Egitim%20Sonrasi%20Uygulama6/6.%20Hafta%20E%C3%84%C2%9Fitim%20Sonras%C3%84%C2%B1%20G%C3%83%C2%B6revleri.ipynb#W1sZmlsZQ%3D%3D?line=5'>6</a> else:
# ----> <a href='vscode-notebook-cell:/Users/serraus/Documents/GitHub/YetGenJumpProjeler/%23%23%206.%20Hafta/Egitim%20Sonrasi%20Uygulama6/6.%20Hafta%20E%C3%84%C2%9Fitim%20Sonras%C3%84%C2%B1%20G%C3%83%C2%B6revleri.ipynb#W1sZmlsZQ%3D%3D?line=6'>7</a>     raise ValueError ("Listede tek sayi var")
#
# ValueError: Listede tek sayi var

# %% [markdown]
# # Problem 2
#
# 2 YetGen lideri ders sırasında canları sıkılınca oyun oynamak isterler. Ancak hangi oyunu oynayacaklarına karar veremezler ve son olarak kendi oyunlarını yazmaya karar verirler.
# Liderlerimizin kodlamak istediği oyun kuralları şöyledir:
# - Oyunda random olarak 0 ile 100 arasında bir sayı tutulur.
# - Kullanıcıdan bilgisayarın tuttuğu sayıyı tahmin etmesi için bir sayı girmesini istenir.
# - Eğer kullanıcının girdiği sayı bulunması gereken sayıdan küçükse  tahmininizi yükseltin, büyükse tahmininizi düşürün şeklinde bir çıktı verilir.
# - Oyunun gerçeğe yakın olması için bilgisayarın çalışmasını simgelemek için 1 saniye bekleme süresi tanınır.
# - Kullanıcı 5 hakkı vardır. 5 hakkı da kullanıp sayıyı bulamazsa oyunu kaybeder.

# %%
import time
import random
print("Sayi tahmin oyunu")
rastgeleSayi = random.randint(1,100)
tahminHakki = 5
while True:
    tahmin = int(input("Tahmininizi giriniz: "))
    if tahmin < rastgeleSayi:
        print("Tahmininiz kontrol ediliyor...")
        time.sleep(1)
        print("Tahmininizi yukseltin")
        tahminHakki -= 1
    elif tahmin > rastgeleSayi:
        print("Tahmininiz kontrol ediliyor...")
        time.sleep(1)
        print("Tahmininizi dusurun")
        tahminHakki -= 1
    else:
        print("Tahmininiz kontrol ediliyor...")
        time.sleep(1)
        print(f"Tebrikler sayi {rastgeleSayi} idi")
        break

    if tahminHakki == 0:
        print("Tahmin hakkiniz bitti")
        print(f"Sayi {rastgeleSayi} idi")
        break
# Out:
# Sayi tahmin oyunu
# Tahmininiz kontrol ediliyor
# Tahmininizi yukseltin
# Tahmininiz kontrol ediliyor
# Tahmininizi dusurun
# Tahmininiz kontrol ediliyor
# Tahmininizi yukseltin
# Tahmininiz kontrol ediliyor
# Tahmininizi dusurun
# Tahmininiz kontrol ediliyor
# Tahmininizi dusurun
# Tahmin hakkiniz bitti
# Sayi 35 idi

# %%
import random
import time

print("Tahmin oyununa hosgeldin")
time.sleep(2)  
print("Bir sayi tutuyorum...")
time.sleep(3)

kullaniciSayi = int(input("Tahmininz: "))
sayi = random.randint(1,100)
hak = 1 

for hak in range(6): 
  while kullaniciSayi != sayi:
    time.sleep(1)
  
 
    if kullaniciSayi < sayi:
      print("Tahmininiz cok dusuk")
      kullaniciSayi = int(input("Yeni tahmin: "))
    
    else:
      print("Tahmininiz cok yuksek")
      kullaniciSayi = int(input("Yeni tahmin: "))
    hak +=1
  if hak == 5:
    break
print(f"Tebrikler! aklimdaki sayi { sayi } idi.")
# Out:
# Tahmin oyununa hosgeldin
# Bir sayi tutuyorum...
# Tahmininiz cok dusuk
# Tahmininiz cok yuksek
# Tahmininiz cok yuksek
# Tahmininiz cok dusuk
# Tahmininiz cok dusuk
# Tahmininiz cok dusuk
# Tahmininiz cok yuksek
# Tahmininiz cok yuksek
