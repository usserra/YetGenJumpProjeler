# %% [markdown]
# # Problem 1
#
# Şimdi beraber kullanıcılardan aldığımız verileri işleyerek, onlara hem çıktı verecek, hem de aldığımız ve hesapladığımız verileri ileride kullanabilmek adına kaydedeceğiz.
#
#
#  **Bu bir veri giriş platformu olacak**
#
#
#  * kullanıcıya kaç giriş yapacağını soracağız
# * kullanıcıdan isim-soyisim, yaş, boy, kilo bilgilerini alarak VKİ hesaplayacağız
# * ardından bunları sınıflara göre kaydedeceğiz bir dosyaya kaydedeceğiz
#
#
# Sınıflar ise şu şekilde:
# * 18, 5 kg/m.'nin altında olanlar: Zayıf
# * 18.5 – 24, 9 kg/m. arasında olanlar: Normal kilolu
# * 25 – 29, 9 kg/m. arasında olanlar: Fazla kilolu
# * 30 – 39, 9 kg/m. arasında olanlar: Obez
# * 40 kg/m.'nin üzerinde olanlar: İleri derecede obez (morbid obez), olarak görülür.

# %%
import time #kayit tarihi icin

def vki_hesaplama(kilo, boy):
    vki = kilo/((boy/100) **2)
    return round(vki,1)

def deger_araligi(vki):
    if vki < 18.5:
        return "zayif"
    elif vki <= 24.9:
        return "normal kilolu"
    elif vki <= 29.9:
        return "fazla kilolu"
    elif vki <= 39.9:
        return "obez"
    elif vki >= 40:
        return "ileri obez"
def cikti_olustur(isim,yas,kilo,boy,vki,deger):
    kayitTarihi = time.ctime(time.time())
    t1 = f"kullanici adi {isim}\n"
    t2 = f"kullanicinin yas, kilo, boy bilgisi {yas}, {kilo}, {boy}\n"
    t3 = f"kullanicinin vucut kitle indexi {vki}\n"
    t4 = f"deger araligi {deger}\n"
    t5 = f"olusturma tarihi: {kayitTarihi}\n"
    output = t1+t2+t3+t4+t5 
    return output

def main():
    giris_sayisi = int(input("Kac giris yapacaksiniz: "))
    for num in range(giris_sayisi):
        print(f"Kullanici kaydi {num+1}")
        isim = input("Isim Soyisim: ")
        yas = int(input("Yas: "))
        boy = float(input("Boy: "))
        kilo = float(input("Kilo: "))
        vki = vki_hesaplama (kilo,boy)
        deger = deger_araligi(vki)
        output = cikti_olustur(isim, yas, kilo, boy, vki, deger)
        with open("saglik.txt", "a") as f:
            f.write(output)
            f.write("*"*20)
            f.write("\n")
            print("Kullanici kaydedildi")
main()
# Out:
# Kullanici kaydi 1
# Kullanici kaydedildi
# Kullanici kaydi 2
# Kullanici kaydedildi

# %% [markdown]
# # Problem 2
# **YetBar - Smoothie Bank**
# ---
# YetBar spor salonunun girişinde bulunan, insansız bir sağlıklı içecek otomatıdır. Kullanıcı çeşitli girdiler smoothie içeceğine koyacağı ürünleri belirleyebilir, fiyat hesaplaması yaptırabilir ya da sadece menüyü görüntüleyebilir.
#
# **Projenin Amacı:**
#
# *   Birbirini etkileyen ve bir kod içerisinde birden fazla defa başvurulacak fonksiyonların oluşturulup, "fonksiyonel" proglamlamak.
# *   Büyük programları yazarken, yazılımcı olarak yapabileceğimiz hatalardan kaçınmak için kontrol yöntemleri geliştirmek.
# *   Kullanıcı inputlarını ve yaptığımız hesapları, raporlamak/loglamak amacıyla kaydetmek.
#
# **Programdan Beklenen Çıktılar**
# * Program kullanıcıya temelde 2 farklı işlem yapma imkanı sağlar.
# > 1. Menüyü görüntüleme
# > 3. Satın alma
# * Satın alınan her içecek tarih, fiyat bilgisi ile kaydedilmeli ve her zaman ulaşılabilir olmalıdır.

# %%
import time

menu = {
            "cilek" : 1, 
            "muz" : 2,
            "elma" : 3, 
            "uzum" : 5,
            "kavun" : 6  }

def display_menu():
    print("______MENU______")
    for item in list(menu.keys()):
        print(f"{item.upper()} : {menu[item]} TL")

def tek_urun_fiyat_hesaplama(urun, adet):
    assert adet >= 0, "Urun adedi 0 ve 0'dan kucuk olamaz."
    if urun not in list(menu.keys()):
        return None
    else:
        return menu[urun] * adet #menu icinde urun fiyati bulup adetle carpiyor
def satin_alma():
    display_menu()
    print("Lutfen satin almak istediginiz urunu giriniz, cikis yapmak icin 0'a basiniz.")
    satin_alinan_urunler = []
    satin_alma_adedi = []

    son_fiyat = 0

    while 1: #1'e basildigi surece dongu devam eder
        eklenecek_urun = input("Hangi urunu eklemek istersiniz?: ")
        if eklenecek_urun == 0:
            print("Fis kaydediliyor")
            break

        ekleme_adedi = int(input("Kac adet eklemek istiyorsunuz?: "))
        fiyat = tek_urun_fiyat_hesaplama(eklenecek_urun, ekleme_adedi)
        if fiyat is None:
            print("Yanlis giris yaptiniz, urun eklenmedi")
        else:
            print(f"Satin alma ucreti: {fiyat}. \nSatin almayi onaylamak icin 'y', iptal etmek icin 'n' giriniz.")
            check = input("Satin almayi onayliyor musunuz?: ")
            if check == 'y':
                print("Satin alim onaylandi")
                print("-"*40)
                son_fiyat += fiyat
                satin_alinan_urunler.append(eklenecek_urun)
                satin_alma_adedi.append(ekleme_adedi)
                print(f"Ara toplam: {son_fiyat}")
            elif check == 'n':
                print("Satin alma islemi iptal edildi")
                print("-"*40)
        return son_fiyat, satin_alinan_urunler, satin_alma_adedi

def main():
    print("YetBar'a hosgeldiniz, menuyu goruntulemek icin 1'e, smoothie yapmak icin 2'ye, cikmak icin 0'a basiniz.")
    program = None #programi bos birak gibi bi sey, sonra usutne ekleme yapilacak

    while 1:
        program =int(input("Tercihiniz: "))
        if program <0 or program >2:
            print("Yanlis tercih yaptiniz, lutfen tekrar deneyiniz")
        elif program == 0:
            print("Cikis yapiliyor...\nSaglikli gunler dileriz")
            break
        elif program == 1:
            display_menu()
        elif program == 2:
            satin_alma_ucreti, satin_alinan_urunler, satin_alma_adedi = satin_alma()

            with open ("kasa.txt", "a") as f:
                f.write(str(time.ctime(time.time()))) 
                f.write("\n")
                f.write(',' .join(map(str, satin_alinan_urunler)))
                f.write("\n")
                f.write(',' .join(map(str, satin_alma_adedi)))
                f.write("\n")
                f.write(f"Toplam: {satin_alma_ucreti}")
                f.write("\n")
                f.write("*"*20)
                f.write("\n")
            cikis_kontrol = input("Baska bir islem yapmak istiyor musunuz? (evet-hayir): ")
            if cikis_kontrol == "evet":
                pass
            else:
                print("\n\nTESEKKURLER")
                break
main()
# Out:
# YetBar'a hosgeldiniz, menuyu goruntulemek icin 1'e, smoothie yapmak icin 2'ye, cikmak icin 0'a basiniz.
# ______MENU______
# CILEK : 1 TL
# MUZ : 2 TL
# ELMA : 3 TL
# UZUM : 5 TL
# KAVUN : 6 TL
# ______MENU______
# CILEK : 1 TL
# MUZ : 2 TL
# ELMA : 3 TL
# UZUM : 5 TL
# KAVUN : 6 TL
# Lutfen satin almak istediginiz urunu giriniz, cikis yapmak icin 0'a basiniz.
# Satin alma ucreti: 3.
# Satin almayi onaylamak icin 'y', iptal etmek icin 'n' giriniz.
# Satin alim onaylandi
# ----------------------------------------
# Ara toplam: 3
# ______MENU______
# CILEK : 1 TL
# MUZ : 2 TL
# ELMA : 3 TL
# UZUM : 5 TL
# KAVUN : 6 TL
# Lutfen satin almak istediginiz urunu giriniz, cikis yapmak icin 0'a basiniz.
# Satin alma ucreti: 2.
# Satin almayi onaylamak icin 'y', iptal etmek icin 'n' giriniz.
# Satin alim onaylandi
# ----------------------------------------
# Ara toplam: 2
#
#
# TESEKKURLER
